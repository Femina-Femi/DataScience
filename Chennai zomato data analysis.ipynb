# %%
#import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default='svg'

# %%
#importing data set
df=pd.read_csv('Zomato Chennai Listing 2020.csv')
df.rename(columns={'Name of Restaurant':'NAME','Price for 2':'PRICE','Cuisine':'CUSINE_CATEGORY','Location':'REGION','Delivery Rating':'RATING','Delivery Rating Count' :'VOTES'},inplace=True)
df.head(2)
# Out:
#                                           Zomato URL                   NAME  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
#
#                                              Address      REGION  \
# 0          336 & 338, Main Road, Pallavaram, Chennai  Pallavaram
# 1   New 14, Old 11/3Q, Railway Station Road, MKN ...     Alandur
#
#                                      CUSINE_CATEGORY  \
# 0                                        ['Biryani']
# 1  ['Biryani', ' North Indian', ' Mughlai', ' Des...
#
#                                           Top Dishes   PRICE Dining Rating  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...   500.0           4.3
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...  1000.0           4.4
#
#   Dining Rating Count RATING  VOTES  \
# 0                1500    4.3   9306
# 1                3059    4.1  39200
#
# ...

# %%
#3.getting basic information about dataset
df.shape
#(15081 -> rows, 12 -> column)
# Out:
# (12032, 12)

# %%
df.info()
# all are not null column and object type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Zomato URL           12032 non-null  object
#  1   NAME                 12032 non-null  object
#  2   Address              12032 non-null  object
#  3   REGION               12032 non-null  object
#  4   CUSINE_CATEGORY      12032 non-null  object
#  5   Top Dishes           12032 non-null  object
#  6   PRICE                12032 non-null  float64
#  7   Dining Rating        12032 non-null  object
#  8   Dining Rating Count  12032 non-null  object
#  9   RATING               12032 non-null  object
#  10  VOTES                12032 non-null  object
#  11  Features             12032 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#               PRICE
# count  12032.000000
# mean     397.611370
# std      332.045938
# min       40.000000
# 25%      200.000000
# 50%      300.000000
# 75%      450.000000
# max     5000.000000

# %%
df
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#                         NAME  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# ...

# %%
#4.cleaning data
#1.replacing none rating and none voting with 0
df['RATING']=df['RATING'].replace('None','0')
df['VOTES']=df['VOTES'].replace('None','0')
df.RATING.unique()
df.VOTES.unique()
print('none rating:' ,df[df['RATING']=='None'])
print('none votes:' ,df[df['VOTES']=='None'])
# Out:
# none rating: Empty DataFrame
# Columns: [Zomato URL, NAME, Address, REGION, CUSINE_CATEGORY, Top Dishes, PRICE, Dining Rating, Dining Rating Count, RATING, VOTES, Features]
# Index: []
# none votes: Empty DataFrame
# Columns: [Zomato URL, NAME, Address, REGION, CUSINE_CATEGORY, Top Dishes, PRICE, Dining Rating, Dining Rating Count, RATING, VOTES, Features]
# Index: []

# %%
#removing null records
df.isnull().sum()
# Out:
# Zomato URL             0
# NAME                   0
# Address                0
# REGION                 0
# CUSINE_CATEGORY        0
# Top Dishes             0
# PRICE                  0
# Dining Rating          0
# Dining Rating Count    0
# RATING                 0
# VOTES                  0
# Features               0
# dtype: int64

# %%
#checking null row one by one and removing and replacing 
df[df['PRICE'].isnull()]
#complete row is not having value so drop it 
#df.drop(15080,inplace=True)
# Out:
# Empty DataFrame
# Columns: [Zomato URL, NAME, Address, REGION, CUSINE_CATEGORY, Top Dishes, PRICE, Dining Rating, Dining Rating Count, RATING, VOTES, Features]
# Index: []

# %%
df[df['PRICE'].isnull()]
# removed
# Out:
# Empty DataFrame
# Columns: [Zomato URL, NAME, Address, REGION, CUSINE_CATEGORY, Top Dishes, PRICE, Dining Rating, Dining Rating Count, RATING, VOTES, Features]
# Index: []

# %%
#replacing other field with na because all are text field
df.fillna('NA',inplace=True)

# %%
df.isnull().sum()
# Out:
# Zomato URL             0
# NAME                   0
# Address                0
# REGION                 0
# CUSINE_CATEGORY        0
# Top Dishes             0
# PRICE                  0
# Dining Rating          0
# Dining Rating Count    0
# RATING                 0
# VOTES                  0
# Features               0
# dtype: int64

# %%
#replacing text with 0
df['RATING'].value_counts()
#rating field is haivng new , -, opening  as values so replacing that with 0 because rating should be number
# Out:
# 0      5851
# 3.9    1383
# 3.8     701
# 4.0     570
# 3.7     559
# 4.1     468
# 3.6     465
# 4.2     401
# 3.5     314
# 4.3     277
# 3.4     259
# 3.3     189
# 4.4     128
# 3.2      93
# 3.1      79
# 3.0      63
# 4.5      55
# 2.9      39
# 2.8      26
# 4.6      24
# 2.7      19
# 2.6      17
# 2.5       9
# 0.3       8
# 2.4       7
# 2.3       5
# 2.2       5
# 2.0       5
# 1.8       5
# 4.7       4
# 2.1       2
# 1.6       1
# 1.5       1
# Name: RATING, dtype: int64

# %%
#checking text values in the column before changing its data type to numbering
df['VOTES'].value_counts()
# Out:
# Not enough Delivery Reviews    3379
# Does not offer Delivery        2252
# 0                               239
# 27                               34
# 40                               30
#                                ...
# 7705                              1
# 6374                              1
# 3677                              1
# 588                               1
# 1617                              1
# Name: VOTES, Length: 2281, dtype: int64

# %%
df['VOTES'].replace(to_replace=['Not enough Delivery Reviews','Does not offer Delivery','Does not offer Delivery'],value=0,inplace=True)
df['VOTES'].value_counts()
# Out:
# 0       5631
# 0        239
# 27        34
# 37        30
# 60        30
#         ...
# 7705       1
# 6374       1
# 3677       1
# 588        1
# 1617       1
# Name: VOTES, Length: 2280, dtype: int64

# %%
df['PRICE']=df['PRICE'].astype('int64')
df['RATING']= df['RATING'].astype('float')
df['VOTES']=df['VOTES'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Zomato URL           12032 non-null  object
#  1   NAME                 12032 non-null  object
#  2   Address              12032 non-null  object
#  3   REGION               12032 non-null  object
#  4   CUSINE_CATEGORY      12032 non-null  object
#  5   Top Dishes           12032 non-null  object
#  6   PRICE                12032 non-null  int64
#  7   Dining Rating        12032 non-null  object
#  8   Dining Rating Count  12032 non-null  object
#  9   RATING               12032 non-null  float64
#  10  VOTES                12032 non-null  int64
#  11  Features             12032 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
df.head(3)
# Out:
#                                           Zomato URL                   NAME  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
# 2  https://www.zomato.com/chennai/ss-hyderabad-bi...   SS Hyderabad Biryani
#
#                                              Address       REGION  \
# 0          336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1   New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2   98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
#
#                                      CUSINE_CATEGORY  \
# 0                                        ['Biryani']
# 1  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  ['Biryani', ' North Indian', ' Chinese', ' Ara...
#
#                                           Top Dishes  PRICE Dining Rating  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...    500           4.3
# ...

# %%
df.isnull().sum()
# Out:
# Zomato URL             0
# NAME                   0
# Address                0
# REGION                 0
# CUSINE_CATEGORY        0
# Top Dishes             0
# PRICE                  0
# Dining Rating          0
# Dining Rating Count    0
# RATING                 0
# VOTES                  0
# Features               0
# dtype: int64

# %%
#removing restaurent record whose rating is 0
uselessdata=(df['RATING']==0.0) |(df['VOTES']==0)
df[uselessdata]
# Out:
#                                               Zomato URL  \
# 15     https://www.zomato.com/chennai/welcome-hotel-p...
# 18     https://www.zomato.com/chennai/wire-room-bar-k...
# 23       https://www.zomato.com/chennai/bff-2-0-ra-puram
# 85     https://www.zomato.com/chennai/bazaar-all-day-...
# 89     https://www.zomato.com/chennai/coal-barbecues-...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#                                                NAME  \
# 15                                    Welcome Hotel
# 18                          Wire Room Bar & Kitchen
# 23                                          BFF 2.0
# 85     Bazaar - All Day Diner - Grand by GRT Hotels
# ...

# %%
df=df[~uselessdata]

# %%
df
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 11901  https://www.zomato.com/chennai/dhabba-on-wheel...
# 11914  https://www.zomato.com/chennai/sandwich-sister...
# 11953  https://www.zomato.com/chennai/the-sandwich-bo...
# 11959  https://www.zomato.com/chennai/the-shangai-sto...
# 11960  https://www.zomato.com/chennai/the-shangai-sto...
#
#                         NAME  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 11901       Dhabba On Wheels
# 11914       Sandwich Sisters
# ...

# %%
temp= df['REGION'].str.split(',',n=1,expand=True)
temp
temp['new'] = temp[0]
temp
df['REGION1']=temp[0]
df['REGION2']=temp[1]
df.head(2)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4192\2207310767.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4192\2207310767.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                           Zomato URL                   NAME  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
#
# ...

# %%
# this will replace region name properly , value after comma will be taken
df.loc[(~df['REGION2'].isnull()), 'REGION'] = df['REGION2']
df
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 11901  https://www.zomato.com/chennai/dhabba-on-wheel...
# 11914  https://www.zomato.com/chennai/sandwich-sister...
# 11953  https://www.zomato.com/chennai/the-sandwich-bo...
# 11959  https://www.zomato.com/chennai/the-shangai-sto...
# 11960  https://www.zomato.com/chennai/the-shangai-sto...
#
#                         NAME  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 11901       Dhabba On Wheels
# 11914       Sandwich Sisters
# ...

# %%
df[~df['REGION2'].isnull()]
# Out:
#                                               Zomato URL  \
# 82     https://www.zomato.com/chennai/burger-king-vel...
# 102    https://www.zomato.com/chennai/mainland-china-...
# 105      https://www.zomato.com/chennai/bhangra-kanathur
# 128    https://www.zomato.com/chennai/601-the-park-nu...
# 132    https://www.zomato.com/chennai/vrindavan-mylapore
# ...                                                  ...
# 11039  https://www.zomato.com/chennai/uzo-sandwich-ch...
# 11074  https://www.zomato.com/chennai/obiryani-koyambedu
# 11169  https://www.zomato.com/chennai/chickpet-donne-...
# 11260  https://www.zomato.com/chennai/sandwich-square...
# 11788  https://www.zomato.com/chennai/house-of-candy-...
#
#                                NAME  \
# 82                      Burger King
# 102                  Mainland China
# 105                         Bhangra
# 128                  601 - The Park
# 132                       Vrindavan
# ...                             ...
# ...

# %%
#9 working on region column
df['REGION']=df['REGION'].str.replace('[a-zA-Z].+-- ','',regex=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4192\1885017395.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['REGION'].value_counts()
# Out:
# Velachery                 214
# Porur                     208
# Anna Nagar East           191
# T. Nagar                  166
# Ambattur                  162
#                          ...
# Somerset Greenways          1
# Foodies Kitchen             1
# Citadines                   1
#  East Coast Road (ECR)      1
#  Koyambedu                  1
# Name: REGION, Length: 148, dtype: int64

# %%
df['REGION'].value_counts()
# Out:
# Velachery                 214
# Porur                     208
# Anna Nagar East           191
# T. Nagar                  166
# Ambattur                  162
#                          ...
# Somerset Greenways          1
# Foodies Kitchen             1
# Citadines                   1
#  East Coast Road (ECR)      1
#  Koyambedu                  1
# Name: REGION, Length: 148, dtype: int64

# %%
#. Removing Duplicate records
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Zomato URL, NAME, Address, REGION, CUSINE_CATEGORY, Top Dishes, PRICE, Dining Rating, Dining Rating Count, RATING, VOTES, Features, REGION1, REGION2]
# Index: []

# %%
# no duplicate record so no need to drop anything
#df=df.drop_duplicates()

# %%
df
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 11901  https://www.zomato.com/chennai/dhabba-on-wheel...
# 11914  https://www.zomato.com/chennai/sandwich-sister...
# 11953  https://www.zomato.com/chennai/the-sandwich-bo...
# 11959  https://www.zomato.com/chennai/the-shangai-sto...
# 11960  https://www.zomato.com/chennai/the-shangai-sto...
#
#                         NAME  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 11901       Dhabba On Wheels
# 11914       Sandwich Sisters
# ...

# %%
#4. Copying the cleaned data into a new DataFrame
zomato_df = df.copy()

# %%
zomato_df.head()
# Out:
#                                           Zomato URL                   NAME  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
# 2  https://www.zomato.com/chennai/ss-hyderabad-bi...   SS Hyderabad Biryani
# 3        https://www.zomato.com/chennai/kfc-perambur                    KFC
# 4  https://www.zomato.com/chennai/tasty-kitchen-p...          Tasty Kitchen
#
#                                              Address       REGION  \
# 0          336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1   New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2   98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
# 3   10, Periyar Nagar, 70 Feet Road, Near Sheeba ...     Perambur
# 4   135B, SRP Colony, Peravallur, Near Perambur, ...     Perambur
#
#                                      CUSINE_CATEGORY  \
# 0                                        ['Biryani']
# ...

# %%
df['CUSINE_CATEGORY'].value_counts()
# Out:
# ['South Indian']                                                         264
# ['Fast Food']                                                            126
# ['Bakery']                                                               121
# ['North Indian', ' Chinese']                                             111
# ['Pizza', ' Fast Food']                                                  106
#                                                                         ...
# ['Arabian', ' Chinese', ' South Indian', ' North Indian', ' Biryani']      1
# ['Arabian', ' North Indian', ' Chinese', ' Seafood']                       1
# ['North Indian', ' Chinese', ' Arabian', ' Biryani', ' Beverages']         1
# ['Finger Food', ' Pizza']                                                  1
# ['Juices', ' Beverages', ' Sandwich', ' Fast Food']                        1
# Name: CUSINE_CATEGORY, Length: 1564, dtype: int64

# %%
df['Features'].value_counts()
# Out:
# ['Home Delivery', 'Indoor Seating']                                                                                            1500
# ['Home Delivery']                                                                                                               526
# ['Delivery Only']                                                                                                               429
# ['Breakfast', 'Home Delivery', 'Indoor Seating']                                                                                277
# ['Home Delivery', 'Indoor Seating', 'Desserts and Bakes']                                                                       216
#                                                                                                                                ...
# ['Breakfast', 'Home Delivery', 'Table Reservation Not Required', 'Indoor Seating']                                                1
# ...

# %%
df['CUSINE TYPE']=df.apply(lambda x:x['CUSINE_CATEGORY'],axis=1)
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4192\3747877564.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 11901  https://www.zomato.com/chennai/dhabba-on-wheel...
# 11914  https://www.zomato.com/chennai/sandwich-sister...
# 11953  https://www.zomato.com/chennai/the-sandwich-bo...
# ...

# %%
#This is Creating Cusin type column
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Desserts and Bakes','Bakery'])), 'CUSINE TYPE'] = 'BAKERY'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Momos',' Chinese','Chinese'])), 'CUSINE TYPE'] = 'CHINESE'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Burger','Wraps','Burmese','Rolls',' Fast Food','Fast Food','Desserts', ' Burger', ' Beverages','Beverages','Ice Cream'])),'CUSINE TYPE']='FAST FOOD'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Seafood','Kerala','Seafood'])),'CUSINE TYPE']='KERALA'
df.loc[df['CUSINE TYPE'].str.contains('Biryani'),'CUSINE TYPE']='BRIYANI'
df.loc[df['CUSINE TYPE'].str.contains('Healthy Food',' Salad'),'CUSINE TYPE']='HEALTHY FOOD'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Mexican','American','American', 'Asian', ' Korean','Thai','Thai', ' Asian','Middle Eastern','Lebanese','Cafe', ' Italian', 'Sandwich',' Sandwich', ' Beverages', ' Continental','Continental', ' Mediterranean', ' American'])), 'CUSINE TYPE'] = 'CONTINENTAL'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Kebab', ' Lebanese', 'BBQ',' BBQ','Raw Meats'])), 'CUSINE TYPE'] = 'BBQ'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Japanese',' Sushi'])), 'CUSINE TYPE'] = 'JAPANESE'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Street Food', ' Mithai','Finger Food','Mithai'])), 'CUSINE TYPE'] = 'FOOD TRUCK'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Arabian', ' Rolls'])), 'CUSINE TYPE'] = 'ARABIAN'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Juices', ' Ice Cream','Tea', ' Coffee'])), 'CUSINE TYPE'] = 'BEVERAGE'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Gujarati','Rajasthani','Naga','Maharashtrian','North Indian', ' Hyderabadi','Bengali'])), 'CUSINE TYPE'] = 'NORTH INDIAN'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Tamil', ' South Indian', ' Seafood','South Indian','Chettinad','Andhra'])), 'CUSINE TYPE'] = 'SOUTH INDIAN'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Tamil', ' South Indian', ' Seafood','South Indian'])), 'CUSINE TYPE'] = 'SOUTH INDIAN'
df.loc[df['CUSINE TYPE'].str.contains('|'.join(['Italian', 'Pizza',' Pizza',' Mexican'])), 'CUSINE TYPE'] = 'ITALIAN'

# %%
#df[df['CUSINE TYPE'] == 'BAKERY']
df['CUSINE TYPE'][217]
# Out:
# 'CHINESE'

# %%
df['CUSINE TYPE'].value_counts()
df.head(2)
# Out:
#                                           Zomato URL                   NAME  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
#
#                                              Address      REGION  \
# 0          336 & 338, Main Road, Pallavaram, Chennai  Pallavaram
# 1   New 14, Old 11/3Q, Railway Station Road, MKN ...     Alandur
#
#                                      CUSINE_CATEGORY  \
# 0                                        ['Biryani']
# 1  ['Biryani', ' North Indian', ' Mughlai', ' Des...
#
#                                           Top Dishes  PRICE Dining Rating  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...    500           4.3
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...   1000           4.4
#
#   Dining Rating Count  RATING  VOTES  \
# 0                1500     4.3   9306
# 1                3059     4.1  39200
#
# ...

# %%
#df['RATING_TYPE'] = ''
df.loc[df['RATING']==5, 'RATING_TYPE'] = 'Excellent'
df.loc[(df['RATING']>=4)& (df['RATING']<5) , 'RATING_TYPE'] = 'Very Good'
df.loc[(df['RATING']>=3)& (df['RATING']<4), 'RATING_TYPE'] = 'Good'
df.loc[(df['RATING']>=2)& (df['RATING']<3), 'RATING_TYPE'] = 'Average'
df.loc[(df['RATING']>=0)& (df['RATING']<2), 'RATING_TYPE'] = 'Bad'

# %%
df.head()
# Out:
#                                           Zomato URL                   NAME  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
# 2  https://www.zomato.com/chennai/ss-hyderabad-bi...   SS Hyderabad Biryani
# 3        https://www.zomato.com/chennai/kfc-perambur                    KFC
# 4  https://www.zomato.com/chennai/tasty-kitchen-p...          Tasty Kitchen
#
#                                              Address       REGION  \
# 0          336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1   New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2   98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
# 3   10, Periyar Nagar, 70 Feet Road, Near Sheeba ...     Perambur
# 4   135B, SRP Colony, Peravallur, Near Perambur, ...     Perambur
#
#                                      CUSINE_CATEGORY  \
# 0                                        ['Biryani']
# ...

# %%
zomato_df = df

# %%
#!pip install -U kaleido

# %%
#5. Performing Exploratory Data Analysis
#) How many restaurants are inchennai for each type of cuisine?


#zomato_df[zomato_df['CITY']!= 'chennai'] only we have mumbai data

fig=px.histogram(zomato_df,x='CUSINE TYPE', color='CUSINE TYPE',
 title= 'No. of Restaurants by Cuisine Type',
 labels={'CUSINE TYPE':'Cuisine Type'})

fig.show()

# %% [markdown]
# # Q2) What are the percentage of restaurants by Rating Type in Chennai?

# %%
rate_df=zomato_df['RATING_TYPE'].value_counts().reset_index()
rate_df.rename(columns={'index':'Rating_type','RATING_TYPE':'COUNT OF RESTAURANTS'},inplace=True)
rate_df
# Out:
#   Rating_type  COUNT OF RESTAURANTS
# 0        Good                  4101
# 1   Very Good                  1927
# 2     Average                   131
# 3         Bad                     3

# %%
fig = px.pie(rate_df, names='Rating_type', values='COUNT OF RESTAURANTS', color='Rating_type',
 title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
#3) Which are the Top 10 highest rated Seafood Restaurant in Chennai?
seafood_df = zomato_df[zomato_df['CUSINE_CATEGORY'].str.contains('Seafood')]
seafood_df.sort_values(by='RATING',ascending=False).head(10)
# Out:
#                                              Zomato URL  \
# 473   https://www.zomato.com/chennai/dynasty-nungamb...
# 2910  https://www.zomato.com/chennai/taj-thalapakatt...
# 96    https://www.zomato.com/chennai/urban-spatula-a...
# 1398  https://www.zomato.com/chennai/nite-bite-saidapet
# 622     https://www.zomato.com/chennai/hotel-runs-adyar
# 903   https://www.zomato.com/chennai/chidambaram-new...
# 195   https://www.zomato.com/chennai/the-marina-nung...
# 376   https://www.zomato.com/chennai/china-town-1-go...
# 661   https://www.zomato.com/chennai/hyderabad-mugha...
# 9380  https://www.zomato.com/chennai/hotel-pandias-v...
#
#                               NAME  \
# 473                        Dynasty
# 2910     Taj Thalapakattu Biriyani
# 96                   Urban Spatula
# 1398                     Nite Bite
# 622                     Hotel Runs
# 903   Chidambaram New Moorthy Cafe
# 195                     The Marina
# 376                     China Town
# ...

# %%
#Q4) Which is the best Food Truck in Chennai?
df[df['CUSINE TYPE']=='Food Truck'].sort_values(by='RATING',ascending=False).head(2)
# Out:
# Empty DataFrame
# Columns: [Zomato URL, NAME, Address, REGION, CUSINE_CATEGORY, Top Dishes, PRICE, Dining Rating, Dining Rating Count, RATING, VOTES, Features, REGION1, REGION2, CUSINE TYPE, RATING_TYPE]
# Index: []

# %%
#Which places have the highest rated restaurant for each Cuisine Type in Chennai?
cusine_rate=df.groupby('CUSINE TYPE').max('RATING').reset_index()
cusine_rate
# Out:
#      CUSINE TYPE  PRICE  RATING  VOTES
# 0        ARABIAN    750     4.2  19700
# 1         BAKERY   1800     4.6   6979
# 2            BBQ    750     4.5  10400
# 3       BEVERAGE    400     4.4   8259
# 4        BRIYANI   2700     4.7  51700
# 5        CHINESE   3000     4.6  59900
# 6    CONTINENTAL   2400     4.6  14500
# 7      FAST FOOD   1500     4.7  19300
# 8   HEALTHY FOOD   1100     4.4   2377
# 9        ITALIAN   1700     4.4  10300
# 10      JAPANESE   2000     4.4    362
# 11        KERALA   1600     4.3   8572
# 12  NORTH INDIAN   2700     4.6  20900
# 13  SOUTH INDIAN   1500     4.6  18800
# 14   STREET FOOD   2000     4.5   7457

# %%
cusine_rate[['CUSINE TYPE','RATING']]
cusine_rate['CUSINE TYPE'][0]
cusine_rate['RATING'][0]
df[df['CUSINE TYPE'] ==cusine_rate['CUSINE TYPE'][0] ]
df
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 11901  https://www.zomato.com/chennai/dhabba-on-wheel...
# 11914  https://www.zomato.com/chennai/sandwich-sister...
# 11953  https://www.zomato.com/chennai/the-sandwich-bo...
# 11959  https://www.zomato.com/chennai/the-shangai-sto...
# 11960  https://www.zomato.com/chennai/the-shangai-sto...
#
#                         NAME  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 11901       Dhabba On Wheels
# 11914       Sandwich Sisters
# ...

# %%
#and (df['RATING']==cusine_rate['RATING'][i]) df.loc[len(df)] = new_row

# Assuming restaurants having rating above 4.5
highest_rated_df = zomato_df[zomato_df['RATING'] >= 4.5]
highest_rated_df
# Out:
#                                               Zomato URL  \
# 62     https://www.zomato.com/chennai/amadora-gourmet...
# 78     https://www.zomato.com/chennai/shri-rajasthani...
# 92     https://www.zomato.com/chennai/fruit-shop-on-g...
# 163    https://www.zomato.com/chennai/momo-sa-khang-b...
# 164    https://www.zomato.com/chennai/la-chocolate-eg...
# ...                                                  ...
# 11043  https://www.zomato.com/chennai/kulfi-treat-t-n...
# 11179  https://www.zomato.com/chennai/chennai-kulfi-k...
# 11377  https://www.zomato.com/chennai/nic-natural-ice...
# 11379  https://www.zomato.com/chennai/nic-natural-ice...
# 11767  https://www.zomato.com/chennai/green-crush-alw...
#
#                                      NAME  \
# 62     Amadora Gourmet Ice Cream & Sorbet
# 78                  Shri Rajasthani Dhaba
# 92              Fruit Shop On Greams Road
# 163      Momo Sa-Khang by Kailash Kitchen
# 164                          La Chocolate
# ...

# %%
fig = px.histogram(highest_rated_df, x='REGION', color='CUSINE TYPE',
 title= 'No. of Best Restaurant for each Cuisine Type by Places')
fig.show()

# %%
#Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Chennai?
highest_rated_price_df = highest_rated_df.groupby(by=['REGION', 'CUSINE TYPE'])['PRICE'].mean().reset_index()
highest_rated_price_df.head()
# Out:
#           REGION   CUSINE TYPE   PRICE
# 0   Guduvancheri  SOUTH INDIAN   600.0
# 1   Nungambakkam       CHINESE  1200.0
# 2     Adambakkam       BRIYANI   300.0
# 3     Adambakkam     FAST FOOD   200.0
# 4          Adyar     FAST FOOD   325.0

# %%
fig = px.scatter(highest_rated_price_df, x="REGION", y="PRICE", color='CUSINE TYPE', symbol='CUSINE TYPE',
 title=' Avg Price Distibution of High rated restaurant for each Cuisine Type').update_traces(marker_size=10)
fig.show()

# %%
#Q7) Which areas have a large number of Chinese Restaurant Market?
chinese_df = zomato_df[zomato_df['CUSINE_CATEGORY'].str.contains('Chinese')]
chinese_df
# Out:
#                                               Zomato URL  \
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# 5      https://www.zomato.com/chennai/dine-n-fun-meda...
# 8      https://www.zomato.com/chennai/savoury-sea-she...
# 9      https://www.zomato.com/chennai/sangeetha-veg-r...
# ...                                                  ...
# 11883  https://www.zomato.com/chennai/hotel-rahman-ch...
# 11886  https://www.zomato.com/chennai/hotel-rahman-me...
# 11887  https://www.zomato.com/chennai/hotel-rahman-ol...
# 11959  https://www.zomato.com/chennai/the-shangai-sto...
# 11960  https://www.zomato.com/chennai/the-shangai-sto...
#
#                            NAME  \
# 2          SS Hyderabad Biryani
# 4                 Tasty Kitchen
# 5                    Dine N Fun
# 8             Savoury Sea Shell
# 9      Sangeetha Veg Restaurant
# ...                         ...
# 11883              Hotel Rahman
# ...

# %%
chinese_rest_df = chinese_df.groupby(by='REGION').agg({'NAME' : 'count', 'PRICE' : 'mean'}).rename(columns= {'NAME' : 'COUNT OF RESTAURANTS'})
chinese_rest_df = chinese_rest_df.sort_values('COUNT OF RESTAURANTS', ascending=False).head(25)
chinese_rest_df.head()
chinese_rest_df.reset_index(inplace=True)

# %%
fig = px.bar(chinese_rest_df, x='REGION', y='COUNT OF RESTAURANTS', color='PRICE', title= 'No. of Chinese Restaurant by')
fig.show()

# %%
#Q8) Is there a relation between Price and Rating by each Cuisine Type?

price_rating_df = zomato_df.groupby(['CUSINE TYPE', 'RATING'])['PRICE'].mean().reset_index()
price_rating_df
# Out:
#      CUSINE TYPE  RATING       PRICE
# 0        ARABIAN     3.2  300.000000
# 1        ARABIAN     3.4  350.000000
# 2        ARABIAN     3.7  375.000000
# 3        ARABIAN     3.8  366.666667
# 4        ARABIAN     3.9  210.000000
# ..           ...     ...         ...
# 243  STREET FOOD     4.1  300.000000
# 244  STREET FOOD     4.2  226.000000
# 245  STREET FOOD     4.3  235.000000
# 246  STREET FOOD     4.4  250.000000
# 247  STREET FOOD     4.5  233.333333
#
# [248 rows x 3 columns]

# %%
fig = px.line(price_rating_df, y="PRICE", x="RATING",color='CUSINE TYPE')
fig.show()

# %%
#Q9) Is there a relation between Region and Price?
region_price_df = zomato_df.groupby(['REGION'])['PRICE'].mean().reset_index()
region_price_df
# Out:
#             REGION        PRICE
# 0            Adyar   500.000000
# 1         Alwarpet  1150.000000
# 2         Ambattur   428.947368
# 3        Ambattur    300.000000
# 4     Aminijikarai   500.000000
# ..             ...          ...
# 143         Vepery   315.217391
# 144   Vettuvankeni   475.000000
# 145  Virugambakkam   410.000000
# 146   Washermenpet   366.346154
# 147  West Mambalam   277.142857
#
# [148 rows x 2 columns]

# %%
fig = px.scatter(region_price_df, x="REGION", y="PRICE").update_traces(marker_size=8)
fig.show()

# %%
#Q10) Find the list of Affordable Restaurants?
'''
The criteria for Affordable Restaurants would be:-
1) Low Price 2) High Rated
First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our dataframe.
Let me explain:-The most expensive restaurant has an average meal cost= 6000. We'll try to stay economical and only pick the
restaurants that are 1/4th of 6000
'''
max_price = zomato_df['PRICE'].max()
one_fourth_price = max_price/4
one_fourth_price
# Out:
# 750.0

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauran
aff_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE']]
aff_rest_df = aff_rest_df[aff_rest_df['PRICE'] <= 1250]
aff_rest_df.sort_values(by='PRICE', inplace=True)
aff_rest_df
# Out:
#                    NAME  PRICE  \
# 2511     Rose Milk Raja    100
# 3542  Vijayarams Coffee    100
# 2151           Cane 4 U    100
# 7133  Rani Sadhana Cafe    100
# 3668          Snack Box    100
# ...                 ...    ...
# 376          China Town   1200
# 2484      Aki Bay @ TVR   1200
# 165      Copper Chimney   1200
# 316    Prive Restaurant   1200
# 213    Tuscana Pizzeria   1200
#
#                                         CUSINE_CATEGORY        REGION  \
# 2511                                      ['Beverages']   Maduravoyal
# 3542  ['Cafe', ' Bakery', ' Juices', ' North Indian'...      T. Nagar
# 2151                                      ['Beverages']  Besant Nagar
# 7133            ['South Indian', ' Chinese', ' Juices']  Purasavakkam
# 3668         ['Street Food', ' Fast Food', ' Sandwich']       Kilpauk
# ...                                                 ...           ...
# 376                             ['Chinese', ' Seafood']   Gopalapuram
# ...

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauranaff_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE']]
aff_rest_df = aff_rest_df[aff_rest_df['PRICE'] <= 1250]
aff_rest_df.sort_values(by='PRICE', inplace=True)
aff_rest_df
# Out:
#                            NAME  PRICE  \
# 2511             Rose Milk Raja    100
# 2278        Prithvika Fast Food    100
# 6110            Roasters Coffee    100
# 11051               Kulfi Treat    100
# 4372   Thattu Vadai Settu Kadai    100
# ...                         ...    ...
# 541                    Yaki BBQ   1200
# 280                        Hola   1200
# 316            Prive Restaurant   1200
# 504                     Goddy's   1200
# 213            Tuscana Pizzeria   1200
#
#                                          CUSINE_CATEGORY        REGION  \
# 2511                                       ['Beverages']   Maduravoyal
# 2278                        ['South Indian', ' Chinese']     Ramapuram
# 6110                                       ['Beverages']     Chromepet
# 11051                                      ['Ice Cream']         Porur
# 4372                                     ['Street Food']     Teynampet
# ...

# %%
# Finding the highest rated list of restaurants
highrate_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE','RATING']]
highrate_rest_df = highrate_rest_df[highrate_rest_df['RATING'] >= 4.5]
highrate_rest_df.sort_values(by='PRICE', inplace=True)
highrate_rest_df
# Out:
#                                      NAME  PRICE  \
# 2151                             Cane 4 U    100
# 11043                         Kulfi Treat    100
# 2598             NIC - Natural Ice Creams    150
# 11377            NIC - Natural Ice Creams    150
# 3875                  A AA E EE Soup Shop    150
# ...                                   ...    ...
# 62     Amadora Gourmet Ice Cream & Sorbet    500
# 4742                             Cococane    600
# 384                              Firdouse    800
# 164                          La Chocolate    800
# 473                               Dynasty   1200
#
#                                          CUSINE_CATEGORY         REGION  \
# 2151                                       ['Beverages']   Besant Nagar
# 11043           ['Desserts', ' Ice Cream', ' Beverages']       T. Nagar
# 2598                                       ['Ice Cream']       T. Nagar
# 11377                                      ['Ice Cream']       Mylapore
# ...

# %%
#Now, we'll merge the aff_rest_df with highrate_rest_df to obtain the intersection i.e the list of Affordable Restaurants !!

highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['NAME', 'REGION'])
highrate_aff_df = highrate_aff_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
highrate_aff_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
 'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

# %%
# Affordable Restaurants with low price and high rating 
highrate_aff_df
# Out:
#                                                  NAME  PRICE  \
# 0                                         Kulfi Treat    100
# 1                                            Cane 4 U    100
# 2                            NIC - Natural Ice Creams    150
# 3                            NIC - Natural Ice Creams    150
# 4                                        Bombay Kulfi    150
# ..                                                ...    ...
# 86  The Grand Sweets and Snacks - Amirtham Restaurant    500
# 87                                           Cococane    600
# 88                                           Firdouse    800
# 89                                       La Chocolate    800
# 90                                            Dynasty   1200
#
#                                       CUSINE_CATEGORY         REGION  \
# 0            ['Desserts', ' Ice Cream', ' Beverages']       T. Nagar
# 1                                       ['Beverages']   Besant Nagar
# ...

# %% [markdown]
# # Q10) Find the list of most Reliable Restaurants?
# The criteria for most Reliable Restaurants would be:-
# 1) Low Price 2) High Rated 3) Large No. of Votes
# First step will be to find the restaurants with Votes greater than Mean of Votes

# %%
mean_votes = zomato_df['VOTES'].mean()
mean_votes
# Out:
# 1393.039110678351

# %%
# Finding list of restaurants that have Votes greater than and equal to Mean of Vote
mean_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE', 'VOTES']]
mean_rest_df = mean_rest_df[mean_rest_df['VOTES'] > 177]
mean_rest_df.sort_values(by='VOTES', inplace=True)
mean_rest_df
# Out:
#                             NAME  PRICE  \
# 9619                    Anjappar    700
# 2580           Kollywood Briyani    200
# 10365                Ck's Bakery    350
# 805                Chef's Burger    350
# 509               Craveyard Cafe    650
# ...                          ...    ...
# 8822    Sangeetha Veg Restaurant    500
# 232     Sapthagiri Tiffin Centre    150
# 22     Supriya Andhra Restaurant    650
# 251           Hotelkaar Biriyani    350
# 55                Guntur Gongura    500
#
#                                          CUSINE_CATEGORY          REGION  \
# 9619   ['Chettinad', ' North Indian', ' Chinese', ' S...      Triplicane
# 2580                             ['Chinese', ' Biryani']       Velachery
# 10365  ['Bakery', ' Desserts', ' Fast Food', ' Sandwi...        Navallur
# 805               ['Burger', ' Fast Food', ' Beverages']           Porur
# 509                 ['Cafe', ' Fast Food', ' Beverages']           Adyar
# ...

# %% [markdown]
# # These are the most reliable, highest rated and affordable restaurants:-
# We obtain this dataframe by simply taking the intersection of highrate_aff_df & mean_rest_df
# This dataframe obtained below shows the restaurants whose:
# Cost is below 1250
# Rating is above 4.5
# Votes are above 177

# %%
reliable_rest_df = pd.merge(mean_rest_df, highrate_aff_df, how='inner', on=['NAME', 'REGION'])
reliable_rest_df = reliable_rest_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
reliable_rest_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
 'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

# %%
reliable_rest_df
# Out:
#                         NAME  PRICE  \
# 0                Hashtag BBQ    400
# 1                 Lassi Shop    200
# 2                      ibaco    200
# 3               Ganga Sweets    300
# 4   Kovai Pazhamudir Nilayam    200
# ..                       ...    ...
# 57            Domino's Pizza    400
# 58                  Firdouse    800
# 59     Shri Rajasthani Dhaba    500
# 60            Domino's Pizza    400
# 61      Sangeetha Fast Foods    500
#
#                                       CUSINE_CATEGORY           REGION  \
# 0                                             ['BBQ']       Medavakkam
# 1   ['Beverages', ' Ice Cream', ' Juices', ' Sandw...      Kottivakkam
# 2                                       ['Ice Cream']         Mylapore
# 3   ['Mithai', ' South Indian', ' Chinese', ' Stre...        Red Hills
# 4                            ['Juices', ' Beverages']  Anna Nagar West
# ..                                                ...              ...
# ...
